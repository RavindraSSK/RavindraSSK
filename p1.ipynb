# %% [markdown]
# <a href="https://colab.research.google.com/github/RavindraSSK/RavindraSSK/blob/main/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

books = []

for i in range(1, 10):  # Reduced range for faster testing
    url = f"https://www.linkedin.com/jobs/search/?currentJobId=4152000846&geoId=103644278&keywords=computer%20science&origin=JOB_SEARCH_PAGE_KEYWORD_AUTOCOMPLETE&refresh=true&start={i}"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')

    job_listings = soup.find_all('div', class_='base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card')

    for job_listing in job_listings:
        title_element = job_listing.find('h3', class_='base-search-card__title')
        location_element = job_listing.find('span', class_='job-search-card__location')
        link_element = job_listing.find('a', class_='base-card__full-link')

        if title_element and location_element and link_element:
            title = title_element.text.strip()
            location = location_element.text.strip()
            link = link_element['href']

            books.append([title, location, link])

df = pd.DataFrame(books, columns=["Job Title", "Location", "Link"])
df.to_csv('books.csv', index=False)

print(books)
# Out:
# [['Software Engineer - Recent Graduate', 'San Jose, CA', 'https://www.linkedin.com/jobs/view/software-engineer-recent-graduate-at-paypal-4149787322?position=1&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=x%2F1EgRADSvXETsQAK1LKLg%3D%3D'], ['Software Engineer - Recent Graduate', 'Chicago, IL', 'https://www.linkedin.com/jobs/view/software-engineer-recent-graduate-at-paypal-4149785379?position=2&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=rJiOlIoE%2BarG20csxTFgvw%3D%3D'], ['Software Engineer (all levels)', 'San Francisco, CA', 'https://www.linkedin.com/jobs/view/software-engineer-all-levels-at-pomelo-care-4151640775?position=3&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=I2oBcxGdiKUALyslZ5qTWQ%3D%3D'], ['Intern, Software Engineer', 'New York, NY', 'https://www.linkedin.com/jobs/view/intern-software-engineer-at-ticketmaster-4150958124?position=4&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=IY31pWMJUQ4%2FPo5qVEGNvQ%3D%3D'], ['Software Engineer Intern', 'Portland, OR', 'https://www.linkedin.com/jobs/view/software-engineer-intern-at-moda-health-4151646823?position=5&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=C%2Bh2ynvLlxz%2FDJIekSffYw%3D%3D'], ['Software Engineer - AI Platform', 'Mountain View, CA', 'https://www.linkedin.com/jobs/view/software-engineer-ai-platform-at-linkedin-4151579860?position=6&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=K%2BL0t%2BicSqqd3f86Lhc1uQ%3D%3D'], ['Software Engineer Intern, Viewer Home', 'New York, NY', 'https://www.linkedin.com/jobs/view/software-engineer-intern-viewer-home-at-vimeo-4150883735?position=7&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=X%2ByoOJcbtCCIKN3SFHQbXg%3D%3D'], ['Software Engineer Intern', 'Dallas, TX', 'https://www.linkedin.com/jobs/view/software-engineer-intern-at-brinks-home-4150997063?position=8&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=Tgh%2FaWMNsq1gkgJhVoopqQ%3D%3D'], ['Junior Software Developer Intern', 'McLean, VA', 'https://www.linkedin.com/jobs/view/junior-software-developer-intern-at-prescient-edge-4151648892?position=9&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=vQK0%2FPLQvJzecKnoJP4vHw%3D%3D'], ['Software Engineer Intern', 'American Fork, UT', 'https://www.linkedin.com/jobs/view/software-engineer-intern-at-brevium-4151640329?position=10&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=P1kx0uJkynfoDVc64MXbrA%3D%3D'], ['Software Engineer I (Full Time) United States', 'San Jose, CA', 'https://www.linkedin.com/jobs/view/software-engineer-i-full-time-united-states-at-cisco-4150508062?position=11&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=B9mcVecD%2FMIQekn7xRAUew%3D%3D'], ['Software Developer', 'Grand Rapids, MI', 'https://www.linkedin.com/jobs/view/software-developer-at-cavallo-4151640483?position=12&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=t1sPi0VVr0PKaXaet%2Ft7pQ%3D%3D'], ['Junior Cyber Security Analyst', 'Charleston, SC', 'https://www.linkedin.com/jobs/view/junior-cyber-security-analyst-at-fathom-4-llc-4151394454?position=13&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=VvdQwyyGW3n5ur%2BY8a8yBw%3D%3D'], ['Entry Level Software Developer', 'Vienna, VA', 'https://www.linkedin.com/jobs/view/entry-level-software-developer-at-eai-technologies-4151639211?position=14&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=%2FT0p1eTDCtJUSx1poaMo5g%3D%3D'], ['Software Engineer (Intern)', 'San Francisco, CA', 'https://www.linkedin.com/jobs/view/software-engineer-intern-at-naptha-ai-4151321450?position=15&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=BIhPO%2FBlfFJfByeK8b9ApA%3D%3D'], ['Software Developer Intern', 'United States', 'https://www.linkedin.com/jobs/view/software-developer-intern-at-imagetrend-4150878982?position=16&pageNum=0&refId=kNXWFeriu6P0s2O0Rd3P1g%3D%3D&trackingId=bI6IusyJ5IhJhiPbw7iH%2Bg%3D%3D'], ['Software Engineering Intern', 'Beaverton, OR', 'https://www.linkedin.com/jobs/view/software-engineering-intern ...
