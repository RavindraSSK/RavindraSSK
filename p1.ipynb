# %% [markdown]
# <a href="https://colab.research.google.com/github/RavindraSSK/RavindraSSK/blob/main/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

jobs = []

for i in range(1, 10):  # Reduced range for faster testing
    url = f"https://www.linkedin.com/jobs/search/?currentJobId=4152000846&geoId=103644278&keywords=computer%20science&origin=JOB_SEARCH_PAGE_KEYWORD_AUTOCOMPLETE&refresh=true&start={i}"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')

    job_listings = soup.find_all('div', class_='base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card')

    for job_listing in job_listings:
        title_element = job_listing.find('h3', class_='base-search-card__title')
        location_element = job_listing.find('span', class_='job-search-card__location')
        link_element = job_listing.find('a', class_='base-card__full-link')

        if title_element and location_element and link_element:
            title = title_element.text.strip()
            location = location_element.text.strip()
            link = link_element['href']

            jobs.append([title, location, link])

df = pd.DataFrame(jobs, columns=["Job Title", "Location", "Link"])
df.to_csv('jobs.csv', index=False)

print(jobs)
# Out:
# [['IT Intern', 'Chicago, IL', 'https://www.linkedin.com/jobs/view/it-intern-at-barstool-sports-4153018442?position=1&pageNum=0&refId=lYe400xrNFHeEkMmX7CjMA%3D%3D&trackingId=bzpx0AHwn%2FvpYlLQBNWilA%3D%3D'], ['Data Analyst', 'Plano, TX', 'https://www.linkedin.com/jobs/view/data-analyst-at-north-texas-tollway-authority-4153126359?position=2&pageNum=0&refId=lYe400xrNFHeEkMmX7CjMA%3D%3D&trackingId=AHjwyTXk%2Fmhbn%2BOnC0r%2BVA%3D%3D'], ['Software Developer I', 'Dallas, TX', 'https://www.linkedin.com/jobs/view/software-developer-i-at-siepe-4157133972?position=3&pageNum=0&refId=lYe400xrNFHeEkMmX7CjMA%3D%3D&trackingId=sa7yRCp2U5QcW1NNHyfwOA%3D%3D'], ['**.******** ********', '*******, **', 'https://www.linkedin.com/jobs/view/jr-software-engineer-at-ascending-inc-4153418431?position=4&pageNum=0&refId=lYe400xrNFHeEkMmX7CjMA%3D%3D&trackingId=IW91m%2BYSZuiwVodXG5QIsw%3D%3D'], ['**** *******', '****** ******', 'https://www.linkedin.com/jobs/view/data-analyst-at-agero-inc-4153177470?position=5&page
# ...

# %% [markdown]
# # New Section
